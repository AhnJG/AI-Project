# %%
# 영상 1초당 25~26장의 이미지 생성 (카카오 다운로드)
# ref. https://www.geeksforgeeks.org/extract-images-from-video-in-python/

# Importing all necessary libraries 
import cv2 
import os

# %%
data_name = 'video_receipt2.mp4'
data_path = os.getcwd()+'/data/'+data_name

#print(os.getcwd()+'/data/'+data_name)
#print(data_name[0:-4])

# %%
#slice .mp4
dir_name = data_name[0:-4]

try:       
    # creating a folder named data 
    if not os.path.exists('./img/' + dir_name):
        os.makedirs('./img/' + dir_name) 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of ' + dir_name)

# %%
# Read the video from specified path 
cam = cv2.VideoCapture(data_path) 
  
# frame 
currentframe = 0
  
while(True): 
      
    # reading from frame 
    ret,frame = cam.read() 
  
    if ret: 
        # if video is still left continue creating images 
        name = './img/'+ data_name[0:-4] + '/img'+ str(currentframe) + '.png'
        print ('Creating...' + name) 
  
        # writing the extracted images 
        cv2.imwrite(name, frame) 
  
        # increasing counter so that it will 
        # show how many frames are created 
        currentframe += 1
    else: 
        break
  
# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# Creating..../img/video_receipt2/img0.png
# Creating..../img/video_receipt2/img1.png
# Creating..../img/video_receipt2/img2.png
# Creating..../img/video_receipt2/img3.png
# Creating..../img/video_receipt2/img4.png
# Creating..../img/video_receipt2/img5.png
# Creating..../img/video_receipt2/img6.png
# Creating..../img/video_receipt2/img7.png
# Creating..../img/video_receipt2/img8.png
# Creating..../img/video_receipt2/img9.png
# Creating..../img/video_receipt2/img10.png
# Creating..../img/video_receipt2/img11.png
# Creating..../img/video_receipt2/img12.png
# Creating..../img/video_receipt2/img13.png
# Creating..../img/video_receipt2/img14.png
# Creating..../img/video_receipt2/img15.png
# Creating..../img/video_receipt2/img16.png
# Creating..../img/video_receipt2/img17.png
# Creating..../img/video_receipt2/img18.png
# Creating..../img/video_receipt2/img19.png
# Creating..../img/video_receipt2/img20.png
# Creating..../img/video_receipt2/img21.png
# ...
